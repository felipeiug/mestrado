# %%
# Out:
# [EXTRACT] zips\14S525ZN.zip
# [EXTRACT] zips\14S51_ZN.zip
# [EXTRACT] zips\14S48_ZN.zip
# [EXTRACT] zips\14S465ZN.zip
# [EXTRACT] zips\14S495ZN.zip
# [EXTRACT] zips\14S45_ZN.zip
# [EXTRACT] zips\14S42_ZN.zip
# [EXTRACT] zips\14S435ZN.zip
# [READ] rasters\14S48_ZN.tif
# [READ] rasters\14S525ZN.tif
# [READ] rasters\14S51_ZN.tif
# [READ] rasters\14S435ZN.tif
# [READ] rasters\14S465ZN.tif
# [READ] rasters\14S42_ZN.tif
# [READ] rasters\14S45_ZN.tif
# [READ] rasters\14S495ZN.tif
# [OK] Unindo: http://www.dsr.inpe.br/topodata/data/geotiff/14S48_ZN.zip
# [MERGE] Unido...
# [EXTRACT] zips\14S405ZN.zip
# [OK] Unindo: http://www.dsr.inpe.br/topodata/data/geotiff/14S51_ZN.zip
# [EXTRACT] zips\15S525ZN.zip
# [EXTRACT] zips\15S51_ZN.zip
# [EXTRACT] zips\15S48_ZN.zip
# [EXTRACT] zips\15S495ZN.zip
# [EXTRACT] zips\15S465ZN.zip
# [EXTRACT] zips\15S45_ZN.zip
# [EXTRACT] zips\15S435ZN.zip
# [MERGE] Unido...
# [OK] Unindo: http://www.dsr.inpe.br/topodata/data/geotiff/14S525ZN.zip
# ...
